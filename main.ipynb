# %%
import psycopg2
import csv
import pandas as pd

conn = psycopg2.connect(dbname='adb', host='172.16.10.22', port='5432',
                        user='rpa_robot', password='Qaz123123+')

cur = conn.cursor(name='1583_first_part')

query = f"""
select dss.source_store_id, dss.store_number, dss.name_1c, ds.store_name from dwh_data.dim_store_src dss
left join dwh_data.dim_store ds on  ds.source_store_id = dss.source_store_id 
where ds.store_name like '%Торговый%' and dss.name_1c notNULL
group by dss.source_store_id, dss.store_number, dss.name_1c, ds.store_name
order by dss.source_store_id
"""

cur.execute(query)

print('Executed')

df1 = pd.DataFrame(cur.fetchall())

cur.close()
conn.close()
# Out:
# Executed

# %%
df1.columns = ['store_id', 'store_number', 'name_1c', 'store_name']
df1
# Out:
#      store_id  store_number  \
# 0           4           101
# 1          96           104
# 2         102           112
# 3         105           120
# 4         116           501
# ..        ...           ...
# 340      2889          1571
# 341      2970          1594
# 342      2975          1599
# 343      2989          1569
# 344      3012          1609
#
#                                                name_1c             store_name
# 0         Алматинский филиал №1 ТОО"Magnum Cash&Carry"     Торговый зал АФ №1
# 1         Алматинский филиал №2 ТОО"Magnum Cash&Carry"     Торговый зал АФ №2
# 2         Алматинский филиал №3 ТОО"Magnum Cash&Carry"     Торговый зал АФ №3
# 3              Филиал ТОО"Magnum Cash&Carry" Караганда     Торговый зал КФ №1
# 4                Филиал ТОО "Magnum Cash&Carry" Астана    Торговый зал АСФ №1
# ..                                                 ...                    ...
# 340     Филиал №81 ТОО "Magnum Cash&Carry" в г. Астана   Торговый зал АСФ №81
# 341     Филиал №86 ТОО "Magnum Сash&Сarry" в г. Алматы    Торговый зал АФ №86
# 342     Филиал №82 ТОО "Magnum Cash&Carry" в г. Астана   Торговый зал АСФ №82
# 343  Филиал ТОО "Magnum Cash&Carry" "Распределитель...  Торговый зал СТМ 5АСФ
# 344  Филиал №83 Товарищества с ограниченной ответст...   Торговый зал АСФ №83
#
# [345 rows x 4 columns]

# %%
import os

files = []

for file in os.listdir(r'\\vault.magnum.local\common\Stuff\_06_Бухгалтерия\! Актуальные ЭЦП'):
    files.append(file)

# %%
df1[df1['store_number'] == 817]
# Out:
# Empty DataFrame
# Columns: [store_id, store_number, name_1c, store_name]
# Index: []

# %%
for i in df1['store_name']:
    print(i)
# Out:
# Торговый зал АФ №1
# Торговый зал АФ №2
# Торговый зал АФ №3
# Торговый зал КФ №1
# Торговый зал АСФ №1
# Торговый зал НСФ №1
# Торговый зал АФ №4
# Торговый зал АФ №5
# Торговый зал АФ №6
# Торговый зал АФ №7
# Торговый зал ШФ №1
# Торговый зал АФ №8
# Торговый зал АФ №10
# Торговый зал АФ №9
# Торговый зал АФ №11
# Торговый зал АФ №12
# Торговый зал ШФ №2
# Торговый зал ТКФ №1
# Торговый зал АФ №14
# Торговый зал АСФ №2
# Торговый зал НСФ №2
# Торговый зал АСФ №3
# Торговый зал НСФ №3
# Торговый зал ТКФ №2
# Торговый зал АФ №16
# Торговый зал АФ №15
# Торговый зал АФ №19
# Торговый зал АФ №17
# Торговый зал ФКС №1
# Торговый зал АФ №20
# Торговый зал НСФ №61
# Торговый зал ППФ №20
# Торговый зал ППФ №21
# Торговый зал КПФ №1
# Торговый зал АСФ №58
# Торговый зал НСФ №58
# Торговый зал УКФ №3
# Торговый зал ППФ №19
# Торговый зал ППФ №22
# Торговый зал АСФ №64
# Торговый зал НСФ №64
# Торговый зал АСФ №65
# Торговый зал НСФ №65
# Торговый зал ППФ №17
# Торговый зал ППФ №2
# Торговый зал ППФ №11
# Торговый зал ППФ №4
# Торговый зал ППФ №5
# Торговый зал ППФ №7
# Торговый зал ППФ №8
# Торговый зал ППФ №13
# Торговый зал ППФ №18
# Торговый зал ППФ №6
# Торговый зал ППФ №10
# Торговый зал ППФ №12
# Торговый зал ППФ №15
# Торговый зал ППФ №9
# Торговый зал ППФ №16
# Торговый зал ППФ №14
# Торговый зал ППФ №3
# Торговый зал АСФ №59
# Торговый зал НСФ №59
# Торговый зал АФ №75
# Торговый зал АСФ №60
# Торговый зал НСФ №60
# Торговый зал ШФ №13
# Торговый зал ШФ №21
# Торговый зал ШФ №22
# Торговый зал ШФ №23
# Торговый зал АФ №70
# Торговый зал ШФ №24
# Торговый зал ШФ №25
# Торговый зал ШФ №26
# Торговый зал ШФ №27
# Торговый зал ШФ №28
# Торговый зал ШФ №29
# Торговый зал ШФ №30
# Торговый зал ШФ №32
# Торговый зал ШФ №33
# Торговый зал ШФ №34
# Торговый зал АСФ №66
# Торговый зал НСФ №66
# Торговый зал АСФ №67
# Торговый зал НСФ №67
# Торговый зал_ОПТ ШФ №35
# Торговый зал АФ №76
# Торговый зал АСФ №68
# Торговый зал НСФ №68
# Торговый зал АСФ №69
# Торговый зал НСФ №69
# Торговый зал АСФ №71
# Торговый зал НСФ №71
# Торговый зал АСФ №73
# Торговый зал НСФ №73
# Торговый зал АСФ №70
# Торговый зал НСФ №70
# Торговый зал АСФ №74
# Торговый зал НСФ №74
# Торговый зал АСФ №72
# Торговый зал НСФ №72
# Торговый зал АСФ №75
# Торговый зал НСФ №75
# Торговый зал АФ №77
# Торговый зал АФ №78
# Торговый зал АСФ №76
# Торговый зал НСФ №76
# Торговый зал АСФ №77
# Торговый зал НСФ №77
# Торговый зал АФ №80
# Торговый зал АФ №82
# Торговый зал АФ №83
# Торговый зал ТФ №4
# Торговый зал СТМ 4АФ ALFA
# Торговый зал АСФ №79
# Торговый зал АФ №84
# Торговый зал АСФ №80
# Торговый зал АСФ №81
# Торговый зал АФ №86
# Торговый зал АСФ №82
# Торговый зал СТМ 5АСФ
# Торговый зал АСФ №83

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\Abdykarim.D\PycharmProjects\robot-1157-DWH\working_path\all.csv', header=None)
df.columns = ['Артикул', 'Подгруппа', 'Наименование товара', 'Ценовой сегмент', 'Филиал', 'Код товара', 'Код филиала', 'Учётные остатки', 'Фактические остатки', 'Свободные остатки', 'Кол-во проблемных']

# %%
df[df['Наименование товара'].str.contains('ЛУК')]['Наименование товара'].unique()
# Out:
# array(['ЛУК КАЗАХСТАН РЕП ОТБОРНЫЙ КГ СЕТКА',
#        'ЛУК РЕП КРУПНЫЙ КАЗАХСТАН КГ СЕТКА',
#        'ЛУК РЕП КУМПИР КАЗАХСТАН КГ СЕТКА',
#        'ЛУК РЕП МОЛОДОЙ КАЗАХСТАН КГ',
#        'ЛУК РЕП СТАНДАРТНЫЙ КАЗАХСТАН КГ СЕТКА',
#        'ЛУК РЕПЧАТЫЙ КАЗАХСТАН КГ', 'ЛУК РЕПЧАТЫЙ КАЗАХСТАН КГ РЕАЛИСТ',
#        'ЛУК РЕПЧАТЫЙ КАЗАХСТАН СТАБ ФОНД КГ',
#        'ЛУК РЕПЧАТЫЙ ОПТ КАЗАХСТАН КГ',
#        'ЛУК РЕПЧАТЫЙ СВЕЖИЙ ОТБОРНЫЙ AF 2,5КГ ШТ',
#        'ЛУК РЕПЧАТЫЙ СВЕЖИЙ СОЦИАЛЬНЫЙ AF 2,5КГ ШТ',
#        'ЛУК РЕПЧАТЫЙ ЭКОНОМ В СЕТКЕ КАЗАХСТАН КГ'], dtype=object)

# %%
for i in df['Код филиала']:
    for j in df[df['Код филиала'] == i]['Подгруппа'].unique():
        print(i, j, '|||', sum(df[(df['Код филиала'] == i) & (df['Подгруппа'] == j)]['Фактические остатки']))
    print('===============\n\n')

# %%
import pandas as pd

df = pd.read_excel(r'C:\Users\Abdykarim.D\PycharmProjects\robot-1157-DWH\working_path\Splitted\Алматинский филиал №1_2023-07-12.xlsx', header=0)
# df.columns = ['Артикул', 'Подгруппа', 'Наименование товара', 'Ценовой сегмент', 'Филиал', 'Код товара', 'Код филиала', 'Учётные остатки', 'Фактические остатки', 'Свободные остатки', 'Кол-во проблемных']
df
# Out:
#           Артикул     Подгруппа  \
# 0   390510-210977       КАПУСТА
# 1   390510-210977       КАПУСТА
# 2   390510-210977       КАПУСТА
# 3   390510-210755       КАПУСТА
# 4   390510-210755       КАПУСТА
# ..            ...           ...
# 68    3951-164530  СОЛЬ ОБЫЧНАЯ
# 69    3951-309155  СОЛЬ ОБЫЧНАЯ
# 70    3951-309154  СОЛЬ ОБЫЧНАЯ
# 71     3951-63803  СОЛЬ ОБЫЧНАЯ
# 72    3951-239372  СОЛЬ ОБЫЧНАЯ
#
#                                Наименование товара Ценовой сегмент  \
# 0                             КАПУСТА КАЗАХСТАН КГ          эконом
# 1                             КАПУСТА КАЗАХСТАН КГ          эконом
# 2                             КАПУСТА КАЗАХСТАН КГ          эконом
# 3                     КАПУСТА КРАСНАЯ КАЗАХСТАН КГ          эконом
# 4                     КАПУСТА КРАСНАЯ КАЗАХСТАН КГ          эконом
# ..                                             ...             ...
# 68  СОЛЬ БАРСКИЕ ПРОДУКТЫ ПИЩЕВАЯ ЙОДИРОВАННАЯ 1КГ          эконом
# 69    СОЛЬ ВСЁ В ДОМ ЙОДИРОВАННАЯ ПОМОЛ №0 1КГ П/П          эконом
# 70    СОЛЬ ВСЁ В ДОМ ЙОДИРОВАННАЯ ПОМОЛ №1 1КГ П/П          эконом
# 71                   СОЛЬ ИЛЕЦКАЯ ЙОДИРОВАННАЯ 1КГ          эконом
# 72       СОЛЬ ХАН ТУЗ ПИЩЕВАЯ ЙОДИРОВАННАЯ 1КГ П/П          эконом
#
#                    Филиал  Код товара  Код филиала  Учётные остатки  \
# 0   Алматинский филиал №1      210977           91           166800
# 1   Алматинский филиал №1      210977          115           477163
# 2   Алматинский филиал №1      210977            4          1751210
# 3   Алматинский филиал №1      210755          115             1962
# 4   Алматинский филиал №1      210755            4            63534
# ..                    ...         ...          ...              ...
# 68  Алматинский филиал №1      164530            4              701
# 69  Алматинский филиал №1      309155            4              320
# 70  Алматинский филиал №1      309154            4              320
# 71  Алматинский филиал №1       63803            4               86
# 72  Алматинский филиал №1      239372            4              197
#
#     Фактические остатки  Свободные остатки  Кол-во проблемных
# 0              166800.0             166800             166800
# 1              477163.0             477163                  0
# 2             1751210.0             440589            1000061
# 3                1962.0               1962                  0
# 4               63534.0              61753               7835
# ..                  ...                ...                ...
# 68                701.0                701                  0
# 69                320.0                320                  0
# 70                320.0                320                  0
# 71                 87.0                 86                  3
# 72                197.0                197                  0
#
# [73 rows x 11 columns]

# %%
dick = dict()
for j in sorted(df['Подгруппа'].unique()):
    print(j, '|||', sum(df[df['Подгруппа'] == j]['Фактические остатки']))
    dick.update({j: sum(df[df['Подгруппа'] == j]['Фактические остатки'])})
dick.get('КАПУСТА')
# print('===============\n\n')
# Out:
# КАПУСТА ||| 2504655.0
# КАРТОФЕЛЬ ||| 18282545.0
# КРУПА ГРЕЧНЕВАЯ ВЕС ||| 426671.0
# ЛУК, ЧЕСНОК ||| 5383625.0
# МАСЛО ПОДСОЛНЕЧНОЕ ||| 9157.1
# МОРКОВЬ ||| 1045257.0
# РИС ВЕС ||| 2804049.438
# САХАР ПЕСОК ||| 15227202.0
# СОЛЬ ОБЫЧНАЯ ||| 4938.0
# 2504655.0

# %%
dick1 = {'РИС ВЕС': 'Рис',
         'КРУПА ГРЕЧНЕВАЯ ВЕС': 'гречневая',
         'МАСЛО ПОДСОЛНЕЧНОЕ': 'подсолнечн',
         'КАПУСТА': 'белокоч',
         'ЛУК, ЧЕСНОК': 'репчатый',
         'МОРКОВЬ': 'Морковь',
         'КАРТОФЕЛЬ': 'Картофель',
         'САХАР ПЕСОК': 'Сахар',
         'СОЛЬ ОБЫЧНАЯ': 'Соль'}

# %%
keys = list(dick.keys())
for i in keys:
    print(i)
    dick[dick1.get(i)] = dick.pop(i)
# Out:
# КАПУСТА
# КАРТОФЕЛЬ
# КРУПА ГРЕЧНЕВАЯ ВЕС
# ЛУК, ЧЕСНОК
# МАСЛО ПОДСОЛНЕЧНОЕ
# МОРКОВЬ
# РИС ВЕС
# САХАР ПЕСОК
# СОЛЬ ОБЫЧНАЯ

# %%
dick
# Out:
# {'белокоч': 2504655.0,
#  'Картофель': 18282545.0,
#  'гречневая': 426671.0,
#  'репчатый': 5383625.0,
#  'подсолнечн': 9157.1,
#  'Морковь': 1045257.0,
#  'Рис': 2804049.438,
#  'Сахар': 15227202.0,
#  'Соль': 4938.0}

# %%
df = pd.read_excel(r'C:\Users\Abdykarim.D\Desktop\Говносрань.xlsx', header=8)
# df = df.iloc[7:]
df = df[df['Ценовой сегмент'] == 'Эконом']
df.head()
# Out:
#    Артикул товара  Код товара Ценовой сегмент  \
# 2   390510-210977      210977          Эконом
# 3   390510-210755      210755          Эконом
# 10  390501-346400      346400          Эконом
# 11  390501-341988      341988          Эконом
# 14  390501-285753      285753          Эконом
#
#                       Название товара  Арт. тов. от произв.  \
# 2                КАПУСТА КАЗАХСТАН КГ                   NaN
# 3        КАПУСТА КРАСНАЯ КАЗАХСТАН КГ                   NaN
# 10             КАРТОФЕЛЬ КАЗАХСТАН КГ                   NaN
# 11               КАРТОФЕЛЬ МОЛОДОЙ КГ                   NaN
# 14  КАРТОФЕЛЬ СОЦИАЛЬНЫЙ КАЗАХСТАН КГ                   NaN
#
#          Название от производителя Тип товарной позиции  2-Категория  \
# 2          ЌЫРЫЌЌАБАТ ЌАЗАЌСТАН КГ                Товар          NaN
# 3    ЌЫЗЫЛ ЌЫРЫЌЌАБАТ ЌАЗАЌСТАН КГ                Товар          NaN
# 10             КАРТОП ЌАЗАЌСТАН КГ                Товар          NaN
# 11                   КАРТОП ЖАС КГ                Товар          NaN
# 14  ЈЛЕУМЕТТІК КАРТОП ЌАЗАЌСТАН КГ                Товар          NaN
#
#                 Группа товаров Ед.изм.  ...  Печатное издание Торговая марка  \
# 2     F150510 КАПУСТА [390510]       г  ...      Неопределено            СОФ
# 3     F150510 КАПУСТА [390510]       г  ...      Неопределено            СОФ
# 10  F150501 КАРТОФЕЛЬ [390501]       г  ...      Неопределено            СОФ
# 11  F150501 КАРТОФЕЛЬ [390501]       г  ...      Неопределено            СОФ
# 14  F150501 КАРТОФЕЛЬ [390501]       г  ...      Неопределено   Неопределено
#
#    Цена по дил.кат.  Сумма по прих.  Сумма по инв.  Учетные остатки  \
# 2              0.32       284477.63      284477.63          2066573
# 3              1.10        57098.14       57098.14            78623
# 10             0.28       896790.11      896790.11          5348478
# 11             0.43       261847.13      261847.13           931012
# 14             0.18        12252.31       12252.31            69306
#
#     Фактические остатки  Свободные остатки  Кол-во проблемных  \
# 2             2066573.0            1854478             995187
# 3               78623.0              76842               7261
# 10            5348478.0            4509283            1025975
# 11             931012.0             931012            1353329
# 14              69306.0              69306              76998
#
#     Сумма по дил. кат.
# 2            661303.36
# 3             86485.30
# 10          1497573.84
# 11           400335.16
# 14            12475.08
#
# [5 rows x 21 columns]

# %%
# for i in df['Группа товаров']:
#     print(i)
for j in sorted(df['Группа товаров'].unique()):
    print(j, '|||', sum(df[df['Группа товаров'] == j]['Фактические остатки']))
# Out:
# F020101 РИС ВЕС [260101] ||| 2804049.438
# F020102 КРУПА ГРЕЧНЕВАЯ ВЕС [260102] ||| 432435.0
# F020501 МАСЛО ПОДСОЛНЕЧНОЕ [260501] ||| 4888.0
# F020901 САХАР ПЕСОК [260901] ||| 15232996.0
# F020905 СОЛЬ ОБЫЧНАЯ [3951] ||| 4940.0
# F150501 КАРТОФЕЛЬ [390501] ||| 6348796.0
# F150502 ЛУК, ЧЕСНОК [390502] ||| 3789291.0
# F150503 МОРКОВЬ [390503] ||| 775959.0
# F150510 КАПУСТА [390510] ||| 2145196.0
