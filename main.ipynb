# %%
import psycopg2
import csv
import pandas as pd

conn = psycopg2.connect(dbname='adb', host='172.16.10.22', port='5432',
                        user='rpa_robot', password='Qaz123123+')

cur = conn.cursor(name='1583_first_part')

query = f"""
select dss.source_store_id, dss.store_number, dss.name_1c, ds.store_name from dwh_data.dim_store_src dss
left join dwh_data.dim_store ds on  ds.source_store_id = dss.source_store_id 
where ds.store_name like '%Торговый%' and dss.name_1c notNULL
group by dss.source_store_id, dss.store_number, dss.name_1c, ds.store_name
order by dss.source_store_id
"""

cur.execute(query)

print('Executed')

df1 = pd.DataFrame(cur.fetchall())

cur.close()
conn.close()
# Out:
# Executed

# %%
df1.columns = ['store_id', 'store_number', 'name_1c', 'store_name']
df1
# Out:
#      store_id  store_number  \
# 0           4           101
# 1          96           104
# 2         102           112
# 3         105           120
# 4         116           501
# ..        ...           ...
# 340      2889          1571
# 341      2970          1594
# 342      2975          1599
# 343      2989          1569
# 344      3012          1609
#
#                                                name_1c             store_name
# 0         Алматинский филиал №1 ТОО"Magnum Cash&Carry"     Торговый зал АФ №1
# 1         Алматинский филиал №2 ТОО"Magnum Cash&Carry"     Торговый зал АФ №2
# 2         Алматинский филиал №3 ТОО"Magnum Cash&Carry"     Торговый зал АФ №3
# 3              Филиал ТОО"Magnum Cash&Carry" Караганда     Торговый зал КФ №1
# 4                Филиал ТОО "Magnum Cash&Carry" Астана    Торговый зал АСФ №1
# ..                                                 ...                    ...
# ...

# %%
import os

files = []

for file in os.listdir(r'\\vault.magnum.local\common\Stuff\_06_Бухгалтерия\! Актуальные ЭЦП'):
    files.append(file)

# %%
df1[df1['store_number'] == 817]
# Out:
# Empty DataFrame
# Columns: [store_id, store_number, name_1c, store_name]
# Index: []

# %%
for i in df1['store_name']:
    print(i)
# Out:
# Торговый зал АФ №1
# Торговый зал АФ №2
# Торговый зал АФ №3
# Торговый зал КФ №1
# Торговый зал АСФ №1
# Торговый зал НСФ №1
# Торговый зал АФ №4
# Торговый зал АФ №5
# Торговый зал АФ №6
# Торговый зал АФ №7
# Торговый зал ШФ №1
# Торговый зал АФ №8
# Торговый зал АФ №10
# Торговый зал АФ №9
# Торговый зал АФ №11
# Торговый зал АФ №12
# Торговый зал ШФ №2
# Торговый зал ТКФ №1
# Торговый зал АФ №14
# Торговый зал АСФ №2
# Торговый зал НСФ №2
# Торговый зал АСФ №3
# Торговый зал НСФ №3
# Торговый зал ТКФ №2
# Торговый зал АФ №16
# Торговый зал АФ №15
# Торговый зал АФ №19
# Торговый зал АФ №17
# Торговый зал ФКС №1
# Торговый зал АФ №20
# Торговый зал АФ №18
# Торговый зал ШФ №4
# Торговый зал КФ №2
# Торговый зал АФ №21
# Торговый зал ППФ №1
# Торговый зал АФ №22
# Торговый зал АФ №23
# Торговый зал ШФ №3
# Торговый зал АФ №24
# Торговый зал АСФ №4
# Торговый зал НСФ №4
# Торговый зал АСФ №5
# Торговый зал НСФ №5
# Торговый зал АФ №25
# Торговый зал КЗФ №1
# Торговый зал АФ №26
# ...

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\Abdykarim.D\PycharmProjects\robot-1157-DWH\working_path\all.csv', header=None)
df.columns = ['Артикул', 'Подгруппа', 'Наименование товара', 'Ценовой сегмент', 'Филиал', 'Код товара', 'Код филиала', 'Учётные остатки', 'Фактические остатки', 'Свободные остатки', 'Кол-во проблемных']

# %%
df[df['Наименование товара'].str.contains('БЕЛ')]
# Out:
#             Артикул    Подгруппа  \
# 714    390501-23474    КАРТОФЕЛЬ
# 715    390501-23474    КАРТОФЕЛЬ
# 716    390501-23474    КАРТОФЕЛЬ
# 717    390501-23474    КАРТОФЕЛЬ
# 718    390501-23474    КАРТОФЕЛЬ
# ...             ...          ...
# 9901  260901-283112  САХАР ПЕСОК
# 9902  260901-283112  САХАР ПЕСОК
# 9903  260901-283112  САХАР ПЕСОК
# 9904  260901-283112  САХАР ПЕСОК
# 9905  260901-283112  САХАР ПЕСОК
#
#                                     Наименование товара Ценовой сегмент  \
# 714                        КАРТОФЕЛЬ БЕЛЫЙ КАЗАХСТАН КГ          эконом
# 715                        КАРТОФЕЛЬ БЕЛЫЙ КАЗАХСТАН КГ          эконом
# 716                        КАРТОФЕЛЬ БЕЛЫЙ КАЗАХСТАН КГ          эконом
# 717                        КАРТОФЕЛЬ БЕЛЫЙ КАЗАХСТАН КГ          эконом
# 718                        КАРТОФЕЛЬ БЕЛЫЙ КАЗАХСТАН КГ          эконом
# ...                                                 ...             ...
# ...

# %%
for i in df['Код филиала']:
    for j in df[df['Код филиала'] == i]['Подгруппа'].unique():
        print(i, j, '|||', sum(df[(df['Код филиала'] == i) & (df['Подгруппа'] == j)]['Фактические остатки']))
    print('===============\n\n')
